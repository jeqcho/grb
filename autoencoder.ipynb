# %%
from ClassiPyGRB import SWIFT
# Packages needed for this notebook
import os
import numpy as np

# %%
import torch
import torch.nn as nn
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
# %matplotlib inline
swift = SWIFT(root_path=r'data', res=64, n_bands=[1, 2, 3, 4, 5])
print(f"Swift/BAT bands selected: {swift.bands_selected}")
# Out:
# Swift/BAT bands selected: ['Time(s)', '15-25keV', '25-50keV', '50-100keV', '100-350keV', '15-350keV']

# %%
data_loaded = np.load(os.path.join(swift.results_path, f'SWIFT_data_{swift.res}res_{"".join(str(b) for b in swift.n_bands)}bands_DFT_True.npz'))
grb_names, features = data_loaded['names'], data_loaded['data']
durations = swift.total_durations(grb_names, t=90)
# Out:
# Finding Durations: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1502/1502 [00:08<00:00, 186.19GRB/s]

# %%
features.shape
# Out:
# (1502, 48000)

# %%
features[0]
# Out:
# array([3.27826857e-04, 8.94158557e-05, 1.61230386e-04, ...,
#        5.67102445e-06, 5.72234663e-06, 2.96175636e-06])

# %%
x = np.linspace(0, features.shape[1], features.shape[1])  # Simulated x-axis values for the spectrum

plt.figure(figsize=(10, 6))
plt.plot(x, features[0])
plt.title('First spectrum')
plt.xlabel('Data Point Index')
plt.ylabel('Intensity')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(np.mean(features,axis=1))
print(np.std(features,axis=1))
# Out:
# [7.08391325e-06 7.00145636e-06 1.31297856e-05 ... 3.74117762e-06
#  2.49947029e-05 1.91853215e-05]
# [1.80608751e-05 1.44879182e-05 2.11228685e-05 ... 8.77317851e-06
#  2.76920412e-05 1.42807089e-05]

# %%
# Normalize the features here
normalized_features = (features - np.mean(features, axis=1, keepdims=1))/np.std(features,axis=1,keepdims=1)
print(normalized_features.shape)
print(np.mean(normalized_features,axis=1))
print(np.std(normalized_features,axis=1))
# Out:
# (1502, 48000)
# [ 3.31586610e-17  9.94759830e-17  4.73695157e-18 ...  2.36847579e-17
#  -4.50010399e-17  1.51582450e-16]
# [1. 1. 1. ... 1. 1. 1.]

# %%
_normalized_features = normalized_features # copy this so rerunning next cell doesn't throw error
_labels = np.zeros(shape=(normalized_features.shape[0],1))

# %%
normalized_features = torch.from_numpy(_normalized_features).to(torch.float32)
labels = torch.from_numpy(_labels).to(torch.float32)

X_train, X_test, class_train, class_test = train_test_split(normalized_features, labels, test_size=0.2, random_state=205)

training_dataset = TensorDataset(X_train, class_train)
test_dataset = TensorDataset(X_test, class_test)

BATCHSIZE = 128
BATCHSIZE_TEST = 256

train_dataloader = DataLoader(training_dataset, batch_size=BATCHSIZE, shuffle=True)
test_dataloader  = DataLoader(test_dataset, batch_size=BATCHSIZE_TEST, shuffle=True)

# %%
INPUT_SIZE      = features.shape[1]
LATENT_SIZE     = 5
HIDDEN_SIZE     = 100

# %%
# Note that this code is largely from https://github.com/LSSTC-DSFP/LSSTC-DSFP-Sessions/tree/main/Sessions/Session14
# First, we will inherit from pytorch Module class; https://pytorch.org/docs/stable/generated/torch.nn.Module.html

class Encoder(nn.Module):
    def __init__(self, seed=205):
        """
        seed: int, random seed for reproducibility
        """
        super(Encoder, self).__init__()
        self.seed = torch.manual_seed(seed)
        # here we are initializing the linear layers. This registeres the layer parameters (W,b) as parameters of the Module
        self.fc1 = nn.Linear(INPUT_SIZE,HIDDEN_SIZE)
        self.fc2 = nn.Linear(HIDDEN_SIZE,LATENT_SIZE)

        # We will initialize weights following a multivariate Gaussian
        nn.init.normal_(self.fc1.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc1.bias, mean=0, std=0.01)
        nn.init.normal_(self.fc2.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc2.bias, mean=0, std=0.01)

    # this defines a forward pass of the network (="applying" the network to some input data)
    def forward(self, x):
        # print(x.dtype)
        # print(self.fc1.weight.dtype)
        # print(self.fc1.bias.dtype) # for debugging dtype mismatch
        x      = torch.nn.LeakyReLU()(self.fc1(x))
        z      = self.fc2(x)
        return z

class Decoder(nn.Module):
    def __init__(self, seed=205):
        """
        seed: int, random seed for reproducibility
        """
        super(Decoder, self).__init__()
        self.seed = torch.manual_seed(seed)
        # Using the encoder, how will you initialize two layers?
        self.fc1 = nn.Linear(LATENT_SIZE,HIDDEN_SIZE)
        self.fc2 = nn.Linear(HIDDEN_SIZE,INPUT_SIZE)

        # Using the endoer, how will you initialize the weights and biases?
        nn.init.normal_(self.fc1.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc1.bias, mean=0, std=0.01)
        nn.init.normal_(self.fc2.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc2.bias, mean=0, std=0.01)

    def forward(self, z):
        # Using the encoder, how will you define the forward pass?
        # I recommend the same activation function!
        z      = torch.nn.LeakyReLU()(self.fc1(z))
        x      = self.fc2(z)
        return x

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        # here we are creating instances of the Encoder and Decoder class
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        z = self.encoder(x)
        x = self.decoder(z)
        return x

# %%
# This creates an instance of the Autoencoder class
AE = Autoencoder()

# %%
# the training loop takes a function that loads the data batch by batch, a model to train, a loss function to train the model on and an optimizer
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    losses = []
    # iterate over the dataset
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction of the model
        pred = model(X)
        # Compute the loss function
        loss = loss_fn(pred,X)

        # Backpropagation; this is where we take the gradient and update the network parameters
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # here we keep track of the loss
        if batch % 10 == 0:
            loss, current = loss.item(), batch * len(X)
            losses.append(loss)
            print(f"train loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    return losses

# the test loop is similar to the training loop, only that we don't take any gradients/don't update the network parameters, but only evaluate
def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss =  0
    with torch.no_grad():
        for (X, y) in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, X).item()

    test_loss /= num_batches
    print(f" Avg test loss: {test_loss:>8f} \n")

    return test_loss

# %%
EPOCHS = 500
LEARNING_RATE = 1e-3


# MeanSquaredError (L2) Loss
loss_fn         = nn.MSELoss()
# Adam Optimizer
optimizer       = torch.optim.Adam(AE.parameters(), lr=LEARNING_RATE)


train_loss = []
test_loss  = []
for t in range(EPOCHS):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loss.append(train_loop(train_dataloader, AE, loss_fn, optimizer))
    test_loss.append(test_loop(test_dataloader, AE, loss_fn))
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# train loss: 1.000065  [    0/ 1201]
#  Avg test loss: 0.845764
#
# Epoch 2
# -------------------------------
# train loss: 0.853760  [    0/ 1201]
#  Avg test loss: 0.689739
#
# Epoch 3
# -------------------------------
# train loss: 0.705719  [    0/ 1201]
#  Avg test loss: 0.568709
#
# Epoch 4
# -------------------------------
# train loss: 0.553434  [    0/ 1201]
#  Avg test loss: 0.523736
#
# Epoch 5
# -------------------------------
# train loss: 0.500221  [    0/ 1201]
#  Avg test loss: 0.486654
#
# Epoch 6
# -------------------------------
# train loss: 0.480343  [    0/ 1201]
#  Avg test loss: 0.443949
#
# Epoch 7
# -------------------------------
# train loss: 0.480909  [    0/ 1201]
#  Avg test loss: 0.411922
#
# Epoch 8
# -------------------------------
# train loss: 0.389201  [    0/ 1201]
#  Avg test loss: 0.402398
#
# Epoch 9
# -------------------------------
# train loss: 0.345214  [    0/ 1201]
#  Avg test loss: 0.370324
#
# Epoch 10
# -------------------------------
# train loss: 0.359383  [    0/ 1201]
#  Avg test loss: 0.349866
#
# Epoch 11
# -------------------------------
# train loss: 0.381727  [    0/ 1201]
#  Avg test loss: 0.345193
#
# Epoch 12
# -------------------------------
# train loss: 0.354304  [    0/ 1201]
#  Avg test loss: 0.327812
#
# Epoch 13
# -------------------------------
# train loss: 0.356325  [    0/ 1201]
#  Avg test loss: 0.349259
#
# Epoch 14
# -------------------------------
# train loss: 0.321709  [    0/ 1201]
#  Avg test loss: 0.360587
#
# Epoch 15
# -------------------------------
# train loss: 0.329779  [    0/ 1201]
#  Avg test loss: 0.328431
#
# Epoch 16
# -------------------------------
# train loss: 0.358504  [    0/ 1201]
#  Avg test loss: 0.338213
#
# Epoch 17
# -------------------------------
# train loss: 0.329537  [    0/ 1201]
#  Avg test loss: 0.333995
#
# Epoch 18
# -------------------------------
# train loss: 0.324067  [    0/ 1201]
#  Avg test loss: 0.334868
#
# Epoch 19
# -------------------------------
# train loss: 0.363046  [    0/ 1201]
#  Avg test loss: 0.352884
#
# Epoch 20
# -------------------------------
# train loss: 0.339101  [    0/ 1201]
#  Avg test loss: 0.337058
#
# Epoch 21
# -------------------------------
# train loss: 0.328265  [    0/ 1201]
#  Avg test loss: 0.339895
#
# Epoch 22
# -------------------------------
# train loss: 0.312005  [    0/ 1201]
#  Avg test loss: 0.349669
#
# Epoch 23
# -------------------------------
# train loss: 0.346757  [    0/ 1201]
#  Avg test loss: 0.333648
#
# Epoch 24
# -------------------------------
# train loss: 0.317042  [    0/ 1201]
#  Avg test loss: 0.338872
#
# Epoch 25
# -------------------------------
# train loss: 0.337175  [    0/ 1201]
#  Avg test loss: 0.324871
#
# Epoch 26
# -------------------------------
# train loss: 0.314291  [    0/ 1201]
#  Avg test loss: 0.322546
#
# Epoch 27
# -------------------------------
# train loss: 0.338844  [    0/ 1201]
#  Avg test loss: 0.333780
#
# Epoch 28
# -------------------------------
# train loss: 0.321100  [    0/ 1201]
#  Avg test loss: 0.315002
#
# Epoch 29
# -------------------------------
# train loss: 0.326186  [    0/ 1201]
#  Avg test loss: 0.325716
#
# Epoch 30
# -------------------------------
# train loss: 0.303909  [    0/ 1201]
#  Avg test loss: 0.327574
#
# Epoch 31
# -------------------------------
# train loss: 0.349176  [    0/ 1201]
#  Avg test loss: 0.325926
#
# Epoch 32
# -------------------------------
# train loss: 0.340781  [    0/ 1201]
#  Avg test loss: 0.335504
#
# Epoch 33
# -------------------------------
# train loss: 0.320946  [    0/ 1201]
#  Avg test loss: 0.341293
#
# Epoch 34
# -------------------------------
# train loss: 0.324434  [    0/ 1201]
#  Avg test loss: 0.319004
#
# Epoch 35
# -------------------------------
# train loss: 0.317929  [    0/ 1201]
#  Avg test loss: 0.342186
#
# Epoch 36
# -------------------------------
# train loss: 0.295709  [    0/ 1201]
#  Avg test loss: 0.335003
#
# Epoch 37
# -------------------------------
# train loss: 0.276074  [    0/ 1201]
#  Avg test loss: 0.331646
#
# Epoch 38
# -------------------------------
# train loss: 0.297987  [    0/ 1201]
#  Avg test loss: 0.308423
#
# Epoch 39
# -------------------------------
# train loss: 0.310549  [    0/ 1201]
#  Avg test loss: 0.333482
#
# Epoch 40
# -------------------------------
# train loss: 0.314042  [    0/ 1201]
#  Avg test loss: 0.307715
#
# Epoch 41
# -------------------------------
# train loss: 0.319902  [    0/ 1201]
#  Avg test loss: 0.312248
#
# Epoch 42
# -------------------------------
# train loss: 0.308415  [    0/ 1201]
#  Avg test loss: 0.325826
#
# Epoch 43
# -------------------------------
# train loss: 0.302146  [    0/ 1201]
#  Avg test loss: 0.319271
#
# Epoch 44
# -------------------------------
# train loss: 0.305453  [    0/ 1201]
#  Avg test loss: 0.332063
#
# Epoch 45
# -------------------------------
# train loss: 0.310769  [    0/ 1201]
#  Avg test loss: 0.320228
#
# Epoch 46
# -------------------------------
# train loss: 0.288032  [    0/ 1201]
#  Avg test loss: 0.322714
#
# Epoch 47
# -------------------------------
# train loss: 0.291115  [    0/ 1201]
#  Avg test loss: 0.311215
#
# Epoch 48
# -------------------------------
# train loss: 0.288275  [    0/ 1201]
#  Avg test loss: 0.309859
#
# Epoch 49
# -------------------------------
# train loss: 0.334959  [    0/ 1201]
#  Avg test loss: 0.327136
#
# Epoch 50
# -------------------------------
# train loss: 0.296001  [    0/ 1201]
#  Avg test loss: 0.348019
#
# Epoch 51
# -------------------------------
# train loss: 0.300413  [    0/ 1201]
#  Avg test loss: 0.321593
#
# Epoch 52
# -------------------------------
# train loss: 0.280685  [    0/ 1201]
#  Avg test loss: 0.333337
#
# Epoch 53
# -------------------------------
# train loss: 0.307527  [    0/ 1201]
#  Avg test loss: 0.309010
#
# Epoch 54
# -------------------------------
# train loss: 0.338646  [    0/ 1201]
#  Avg test loss: 0.316842
#
# Epoch 55
# -------------------------------
# train loss: 0.312038  [    0/ 1201]
#  Avg test loss: 0.329413
#
# Epoch 56
# -------------------------------
# train loss: 0.266943  [    0/ 1201]
#  Avg test loss: 0.311970
#
# Epoch 57
# -------------------------------
# train loss: 0.327646  [    0/ 1201]
#  Avg test loss: 0.318140
#
# Epoch 58
# -------------------------------
# train loss: 0.293188  [    0/ 1201]
#  Avg test loss: 0.320406
#
# Epoch 59
# -------------------------------
# train loss: 0.295850  [    0/ 1201]
#  Avg test loss: 0.328377
#
# Epoch 60
# -------------------------------
# train loss: 0.307432  [    0/ 1201]
#  Avg test loss: 0.309839
#
# Epoch 61
# -------------------------------
# train loss: 0.329578  [    0/ 1201]
#  Avg test loss: 0.313500
#
# Epoch 62
# -------------------------------
# train loss: 0.302756  [    0/ 1201]
#  Avg test loss: 0.307775
#
# Epoch 63
# -------------------------------
# train loss: 0.322068  [    0/ 1201]
#  Avg test loss: 0.305536
#
# Epoch 64
# -------------------------------
# train loss: 0.288564  [    0/ 1201]
#  Avg test loss: 0.314458
#
# Epoch 65
# -------------------------------
# train loss: 0.322456  [    0/ 1201]
#  Avg test loss: 0.323089
#
# Epoch 66
# -------------------------------
# train loss: 0.296777  [    0/ 1201]
#  Avg test loss: 0.309073
#
# Epoch 67
# -------------------------------
# train loss: 0.298565  [    0/ 1201]
#  Avg test loss: 0.316568
#
# Epoch 68
# -------------------------------
# train loss: 0.313072  [    0/ 1201]
#  Avg test loss: 0.303717
#
# Epoch 69
# -------------------------------
# train loss: 0.305380  [    0/ 1201]
#  Avg test loss: 0.321893
#
# Epoch 70
# -------------------------------
# train loss: 0.309468  [    0/ 1201]
#  Avg test loss: 0.324139
#
# Epoch 71
# -------------------------------
# train loss: 0.311716  [    0/ 1201]
#  Avg test loss: 0.310228
#
# Epoch 72
# -------------------------------
# train loss: 0.315615  [    0/ 1201]
#  Avg test loss: 0.317831
#
# Epoch 73
# -------------------------------
# train loss: 0.287636  [    0/ 1201]
#  Avg test loss: 0.277869
#
# Epoch 74
# -------------------------------
# train loss: 0.303587  [    0/ 1201]
#  Avg test loss: 0.322629
#
# Epoch 75
# -------------------------------
# train loss: 0.308340  [    0/ 1201]
#  Avg test loss: 0.300420
#
# Epoch 76
# -------------------------------
# train loss: 0.291249  [    0/ 1201]
#  Avg test loss: 0.315389
#
# Epoch 77
# -------------------------------
# train loss: 0.286837  [    0/ 1201]
#  Avg test loss: 0.314289
#
# Epoch 78
# -------------------------------
# train loss: 0.276861  [    0/ 1201]
#  Avg test loss: 0.295766
#
# Epoch 79
# -------------------------------
# train loss: 0.297499  [    0/ 1201]
#  Avg test loss: 0.308966
#
# Epoch 80
# -------------------------------
# train loss: 0.300080  [    0/ 1201]
#  Avg test loss: 0.329127
#
# Epoch 81
# -------------------------------
# train loss: 0.290113  [    0/ 1201]
#  Avg test loss: 0.306661
#
# Epoch 82
# -------------------------------
# train loss: 0.284420  [    0/ 1201]
#  Avg test loss: 0.328788
#
# Epoch 83
# -------------------------------
# train loss: 0.323038  [    0/ 1201]
#  Avg test loss: 0.289724
#
# Epoch 84
# -------------------------------
# train loss: 0.322903  [    0/ 1201]
#  Avg test loss: 0.318700
#
# Epoch 85
# -------------------------------
# train loss: 0.286342  [    0/ 1201]
#  Avg test loss: 0.323868
#
# Epoch 86
# -------------------------------
# train loss: 0.316089  [    0/ 1201]
#  Avg test loss: 0.324493
#
# Epoch 87
# -------------------------------
# train loss: 0.287765  [    0/ 1201]
#  Avg test loss: 0.313393
#
# Epoch 88
# -------------------------------
# train loss: 0.281645  [    0/ 1201]
#  Avg test loss: 0.325045
#
# Epoch 89
# -------------------------------
# train loss: 0.283744  [    0/ 1201]
#  Avg test loss: 0.313610
#
# Epoch 90
# -------------------------------
# train loss: 0.311610  [    0/ 1201]
#  Avg test loss: 0.319558
#
# Epoch 91
# -------------------------------
# train loss: 0.283197  [    0/ 1201]
#  Avg test loss: 0.306913
#
# Epoch 92
# -------------------------------
# train loss: 0.283632  [    0/ 1201]
#  Avg test loss: 0.312442
#
# Epoch 93
# -------------------------------
# train loss: 0.289283  [    0/ 1201]
#  Avg test loss: 0.315598
#
# Epoch 94
# -------------------------------
# train loss: 0.321595  [    0/ 1201]
#  Avg test loss: 0.295767
#
# Epoch 95
# -------------------------------
# train loss: 0.346531  [    0/ 1201]
#  Avg test loss: 0.322129
#
# Epoch 96
# -------------------------------
# train loss: 0.284124  [    0/ 1201]
#  Avg test loss: 0.297161
#
# Epoch 97
# -------------------------------
# train loss: 0.300332  [    0/ 1201]
#  Avg test loss: 0.304210
#
# Epoch 98
# -------------------------------
# train loss: 0.275824  [    0/ 1201]
#  Avg test loss: 0.313494
#
# Epoch 99
# -------------------------------
# train loss: 0.292114  [    0/ 1201]
#  Avg test loss: 0.296993
#
# Epoch 100
# -------------------------------
# train loss: 0.307835  [    0/ 1201]
#  Avg test loss: 0.300752
#
# Epoch 101
# -------------------------------
# train loss: 0.286616  [    0/ 1201]
#  Avg test loss: 0.317471
#
# Epoch 102
# -------------------------------
# train loss: 0.330634  [    0/ 1201]
#  Avg test loss: 0.341651
#
# Epoch 103
# -------------------------------
# train loss: 0.301322  [    0/ 1201]
#  Avg test loss: 0.317834
#
# Epoch 104
# -------------------------------
# train loss: 0.340342  [    0/ 1201]
#  Avg test loss: 0.314836
#
# Epoch 105
# -------------------------------
# train loss: 0.338770  [    0/ 1201]
#  Avg test loss: 0.326874
#
# Epoch 106
# -------------------------------
# train loss: 0.307236  [    0/ 1201]
#  Avg test loss: 0.309668
#
# Epoch 107
# -------------------------------
# train loss: 0.269526  [    0/ 1201]
#  Avg test loss: 0.295020
#
# Epoch 108
# -------------------------------
# train loss: 0.312445  [    0/ 1201]
#  Avg test loss: 0.307260
#
# Epoch 109
# -------------------------------
# train loss: 0.293059  [    0/ 1201]
#  Avg test loss: 0.320182
#
# Epoch 110
# -------------------------------
# train loss: 0.328711  [    0/ 1201]
#  Avg test loss: 0.319294
#
# Epoch 111
# -------------------------------
# train loss: 0.321143  [    0/ 1201]
#  Avg test loss: 0.311491
#
# Epoch 112
# -------------------------------
# train loss: 0.310482  [    0/ 1201]
#  Avg test loss: 0.301195
#
# Epoch 113
# -------------------------------
# train loss: 0.298198  [    0/ 1201]
#  Avg test loss: 0.297033
#
# Epoch 114
# -------------------------------
# train loss: 0.292753  [    0/ 1201]
#  Avg test loss: 0.309763
#
# Epoch 115
# -------------------------------
# train loss: 0.295206  [    0/ 1201]
#  Avg test loss: 0.301925
#
# Epoch 116
# -------------------------------
# train loss: 0.277067  [    0/ 1201]
#  Avg test loss: 0.310001
#
# Epoch 117
# -------------------------------
# train loss: 0.292444  [    0/ 1201]
#  Avg test loss: 0.289794
#
# Epoch 118
# -------------------------------
# train loss: 0.308444  [    0/ 1201]
#  Avg test loss: 0.333608
#
# Epoch 119
# -------------------------------
# train loss: 0.318089  [    0/ 1201]
#  Avg test loss: 0.317623
#
# Epoch 120
# -------------------------------
# train loss: 0.294828  [    0/ 1201]
#  Avg test loss: 0.327336
#
# Epoch 121
# -------------------------------
# train loss: 0.325725  [    0/ 1201]
#  Avg test loss: 0.289154
#
# Epoch 122
# -------------------------------
# train loss: 0.314365  [    0/ 1201]
#  Avg test loss: 0.309452
#
# Epoch 123
# -------------------------------
# train loss: 0.299497  [    0/ 1201]
#  Avg test loss: 0.326124
#
# Epoch 124
# -------------------------------
# train loss: 0.289761  [    0/ 1201]
#  Avg test loss: 0.317309
#
# Epoch 125
# -------------------------------
# train loss: 0.300714  [    0/ 1201]
#  Avg test loss: 0.311613
#
# Epoch 126
# -------------------------------
# train loss: 0.272753  [    0/ 1201]
#  Avg test loss: 0.305526
#
# Epoch 127
# -------------------------------
# train loss: 0.309626  [    0/ 1201]
#  Avg test loss: 0.324998
#
# Epoch 128
# -------------------------------
# train loss: 0.293254  [    0/ 1201]
#  Avg test loss: 0.344873
#
# Epoch 129
# -------------------------------
# train loss: 0.322167  [    0/ 1201]
#  Avg test loss: 0.321505
#
# Epoch 130
# -------------------------------
# train loss: 0.267700  [    0/ 1201]
#  Avg test loss: 0.299397
#
# Epoch 131
# -------------------------------
# train loss: 0.301369  [    0/ 1201]
#  Avg test loss: 0.324041
#
# Epoch 132
# -------------------------------
# train loss: 0.296855  [    0/ 1201]
#  Avg test loss: 0.286704
#
# Epoch 133
# -------------------------------
# train loss: 0.305026  [    0/ 1201]
#  Avg test loss: 0.343095
#
# Epoch 134
# -------------------------------
# train loss: 0.289220  [    0/ 1201]
#  Avg test loss: 0.324462
#
# Epoch 135
# -------------------------------
# train loss: 0.303062  [    0/ 1201]
#  Avg test loss: 0.314589
#
# Epoch 136
# -------------------------------
# train loss: 0.279731  [    0/ 1201]
#  Avg test loss: 0.317470
#
# Epoch 137
# -------------------------------
# train loss: 0.303731  [    0/ 1201]
#  Avg test loss: 0.306847
#
# Epoch 138
# -------------------------------
# train loss: 0.279931  [    0/ 1201]
#  Avg test loss: 0.336262
#
# Epoch 139
# -------------------------------
# train loss: 0.332510  [    0/ 1201]
#  Avg test loss: 0.326082
#
# Epoch 140
# -------------------------------
# train loss: 0.297782  [    0/ 1201]
#  Avg test loss: 0.315790
#
# Epoch 141
# -------------------------------
# train loss: 0.297230  [    0/ 1201]
#  Avg test loss: 0.316845
#
# Epoch 142
# -------------------------------
# train loss: 0.302501  [    0/ 1201]
#  Avg test loss: 0.308846
#
# Epoch 143
# -------------------------------
# train loss: 0.279882  [    0/ 1201]
#  Avg test loss: 0.312131
#
# Epoch 144
# -------------------------------
# train loss: 0.289720  [    0/ 1201]
#  Avg test loss: 0.303297
#
# Epoch 145
# -------------------------------
# train loss: 0.310960  [    0/ 1201]
#  Avg test loss: 0.318390
#
# Epoch 146
# -------------------------------
# train loss: 0.302472  [    0/ 1201]
#  Avg test loss: 0.318893
#
# Epoch 147
# -------------------------------
# train loss: 0.274927  [    0/ 1201]
#  Avg test loss: 0.306705
#
# Epoch 148
# -------------------------------
# train loss: 0.301892  [    0/ 1201]
#  Avg test loss: 0.345613
#
# Epoch 149
# -------------------------------
# train loss: 0.315857  [    0/ 1201]
#  Avg test loss: 0.331507
#
# Epoch 150
# -------------------------------
# train loss: 0.292646  [    0/ 1201]
#  Avg test loss: 0.309794
#
# Epoch 151
# -------------------------------
# train loss: 0.284264  [    0/ 1201]
#  Avg test loss: 0.308996
#
# Epoch 152
# -------------------------------
# train loss: 0.301120  [    0/ 1201]
#  Avg test loss: 0.318063
#
# Epoch 153
# -------------------------------
# train loss: 0.283125  [    0/ 1201]
#  Avg test loss: 0.316216
#
# Epoch 154
# -------------------------------
# train loss: 0.314705  [    0/ 1201]
#  Avg test loss: 0.317876
#
# Epoch 155
# -------------------------------
# train loss: 0.296105  [    0/ 1201]
#  Avg test loss: 0.322746
#
# Epoch 156
# -------------------------------
# train loss: 0.276111  [    0/ 1201]
#  Avg test loss: 0.306762
#
# Epoch 157
# -------------------------------
# train loss: 0.301303  [    0/ 1201]
#  Avg test loss: 0.315481
#
# Epoch 158
# -------------------------------
# train loss: 0.270342  [    0/ 1201]
#  Avg test loss: 0.322694
#
# Epoch 159
# -------------------------------
# train loss: 0.308942  [    0/ 1201]
#  Avg test loss: 0.328305
#
# Epoch 160
# -------------------------------
# train loss: 0.296720  [    0/ 1201]
#  Avg test loss: 0.301325
#
# Epoch 161
# -------------------------------
# train loss: 0.285882  [    0/ 1201]
#  Avg test loss: 0.329261
#
# Epoch 162
# -------------------------------
# train loss: 0.291401  [    0/ 1201]
#  Avg test loss: 0.323926
#
# Epoch 163
# -------------------------------
# train loss: 0.319960  [    0/ 1201]
#  Avg test loss: 0.305507
#
# Epoch 164
# -------------------------------
# train loss: 0.309422  [    0/ 1201]
#  Avg test loss: 0.313754
#
# Epoch 165
# -------------------------------
# train loss: 0.287481  [    0/ 1201]
#  Avg test loss: 0.307397
#
# Epoch 166
# -------------------------------
# train loss: 0.294456  [    0/ 1201]
#  Avg test loss: 0.325500
#
# Epoch 167
# -------------------------------
# train loss: 0.314979  [    0/ 1201]
#  Avg test loss: 0.316964
#
# Epoch 168
# -------------------------------
# train loss: 0.297348  [    0/ 1201]
#  Avg test loss: 0.317998
#
# Epoch 169
# -------------------------------
# train loss: 0.276011  [    0/ 1201]
#  Avg test loss: 0.327762
#
# Epoch 170
# -------------------------------
# train loss: 0.296490  [    0/ 1201]
#  Avg test loss: 0.322596
#
# Epoch 171
# -------------------------------
# train loss: 0.282196  [    0/ 1201]
#  Avg test loss: 0.326121
#
# Epoch 172
# -------------------------------
# train loss: 0.324910  [    0/ 1201]
#  Avg test loss: 0.309589
#
# Epoch 173
# -------------------------------
# train loss: 0.303900  [    0/ 1201]
#  Avg test loss: 0.304157
#
# Epoch 174
# -------------------------------
# train loss: 0.287851  [    0/ 1201]
#  Avg test loss: 0.320463
#
# Epoch 175
# -------------------------------
# train loss: 0.328564  [    0/ 1201]
#  Avg test loss: 0.330371
#
# Epoch 176
# -------------------------------
# train loss: 0.304370  [    0/ 1201]
#  Avg test loss: 0.342437
#
# Epoch 177
# -------------------------------
# train loss: 0.295421  [    0/ 1201]
#  Avg test loss: 0.307229
#
# Epoch 178
# -------------------------------
# train loss: 0.285960  [    0/ 1201]
#  Avg test loss: 0.312648
#
# Epoch 179
# -------------------------------
# train loss: 0.287129  [    0/ 1201]
#  Avg test loss: 0.318901
#
# Epoch 180
# -------------------------------
# train loss: 0.294180  [    0/ 1201]
#  Avg test loss: 0.279490
#
# Epoch 181
# -------------------------------
# train loss: 0.281153  [    0/ 1201]
#  Avg test loss: 0.316182
#
# Epoch 182
# -------------------------------
# train loss: 0.280846  [    0/ 1201]
#  Avg test loss: 0.315620
#
# Epoch 183
# -------------------------------
# train loss: 0.320719  [    0/ 1201]
#  Avg test loss: 0.317449
#
# Epoch 184
# -------------------------------
# train loss: 0.274937  [    0/ 1201]
#  Avg test loss: 0.315320
#
# Epoch 185
# -------------------------------
# train loss: 0.285792  [    0/ 1201]
#  Avg test loss: 0.348534
#
# Epoch 186
# -------------------------------
# train loss: 0.279279  [    0/ 1201]
#  Avg test loss: 0.341345
#
# Epoch 187
# -------------------------------
# train loss: 0.284386  [    0/ 1201]
#  Avg test loss: 0.302309
#
# Epoch 188
# -------------------------------
# train loss: 0.297899  [    0/ 1201]
#  Avg test loss: 0.296457
#
# Epoch 189
# -------------------------------
# train loss: 0.282427  [    0/ 1201]
#  Avg test loss: 0.337144
#
# Epoch 190
# -------------------------------
# train loss: 0.286376  [    0/ 1201]
#  Avg test loss: 0.334047
#
# Epoch 191
# -------------------------------
# train loss: 0.266481  [    0/ 1201]
#  Avg test loss: 0.336530
#
# Epoch 192
# -------------------------------
# train loss: 0.281798  [    0/ 1201]
#  Avg test loss: 0.339857
#
# Epoch 193
# -------------------------------
# train loss: 0.273291  [    0/ 1201]
#  Avg test loss: 0.306826
#
# Epoch 194
# -------------------------------
# train loss: 0.296201  [    0/ 1201]
#  Avg test loss: 0.331426
#
# Epoch 195
# -------------------------------
# train loss: 0.304749  [    0/ 1201]
#  Avg test loss: 0.307378
#
# Epoch 196
# -------------------------------
# train loss: 0.302412  [    0/ 1201]
#  Avg test loss: 0.330478
#
# Epoch 197
# -------------------------------
# train loss: 0.267357  [    0/ 1201]
#  Avg test loss: 0.296946
#
# Epoch 198
# -------------------------------
# train loss: 0.273487  [    0/ 1201]
#  Avg test loss: 0.309989
#
# Epoch 199
# -------------------------------
# train loss: 0.290275  [    0/ 1201]
#  Avg test loss: 0.337462
#
# Epoch 200
# -------------------------------
# train loss: 0.243932  [    0/ 1201]
#  Avg test loss: 0.322657
#
# Epoch 201
# -------------------------------
# train loss: 0.286585  [    0/ 1201]
#  Avg test loss: 0.304159
#
# Epoch 202
# -------------------------------
# train loss: 0.289373  [    0/ 1201]
#  Avg test loss: 0.311269
#
# Epoch 203
# -------------------------------
# train loss: 0.301981  [    0/ 1201]
#  Avg test loss: 0.328149
#
# Epoch 204
# -------------------------------
# train loss: 0.253608  [    0/ 1201]
#  Avg test loss: 0.327206
#
# Epoch 205
# -------------------------------
# train loss: 0.304073  [    0/ 1201]
#  Avg test loss: 0.321854
#
# Epoch 206
# -------------------------------
# train loss: 0.271881  [    0/ 1201]
#  Avg test loss: 0.293475
#
# Epoch 207
# -------------------------------
# train loss: 0.297664  [    0/ 1201]
#  Avg test loss: 0.341177
#
# Epoch 208
# -------------------------------
# train loss: 0.255129  [    0/ 1201]
#  Avg test loss: 0.320555
#
# Epoch 209
# -------------------------------
# train loss: 0.297776  [    0/ 1201]
#  Avg test loss: 0.310232
#
# Epoch 210
# -------------------------------
# train loss: 0.315121  [    0/ 1201]
#  Avg test loss: 0.328850
#
# Epoch 211
# -------------------------------
# train loss: 0.249203  [    0/ 1201]
#  Avg test loss: 0.325180
#
# Epoch 212
# -------------------------------
# train loss: 0.302950  [    0/ 1201]
#  Avg test loss: 0.331291
#
# Epoch 213
# -------------------------------
# train loss: 0.281902  [    0/ 1201]
#  Avg test loss: 0.317660
#
# Epoch 214
# -------------------------------
# train loss: 0.301153  [    0/ 1201]
#  Avg test loss: 0.311591
#
# Epoch 215
# -------------------------------
# train loss: 0.302206  [    0/ 1201]
#  Avg test loss: 0.335874
#
# Epoch 216
# -------------------------------
# train loss: 0.291857  [    0/ 1201]
#  Avg test loss: 0.334840
#
# Epoch 217
# -------------------------------
# train loss: 0.260541  [    0/ 1201]
#  Avg test loss: 0.331026
#
# Epoch 218
# -------------------------------
# train loss: 0.270591  [    0/ 1201]
#  Avg test loss: 0.321454
#
# Epoch 219
# -------------------------------
# train loss: 0.313097  [    0/ 1201]
#  Avg test loss: 0.325281
#
# Epoch 220
# -------------------------------
# train loss: 0.304287  [    0/ 1201]
#  Avg test loss: 0.306112
#
# Epoch 221
# -------------------------------
# train loss: 0.274519  [    0/ 1201]
#  Avg test loss: 0.318260
#
# Epoch 222
# -------------------------------
# train loss: 0.323513  [    0/ 1201]
#  Avg test loss: 0.314834
#
# Epoch 223
# -------------------------------
# train loss: 0.291835  [    0/ 1201]
#  Avg test loss: 0.316436
#
# Epoch 224
# -------------------------------
# train loss: 0.304728  [    0/ 1201]
#  Avg test loss: 0.289034
#
# Epoch 225
# -------------------------------
# train loss: 0.324748  [    0/ 1201]
#  Avg test loss: 0.329453
#
# Epoch 226
# -------------------------------
# train loss: 0.289602  [    0/ 1201]
#  Avg test loss: 0.332732
#
# Epoch 227
# -------------------------------
# train loss: 0.301789  [    0/ 1201]
#  Avg test loss: 0.314240
#
# Epoch 228
# -------------------------------
# train loss: 0.298256  [    0/ 1201]
#  Avg test loss: 0.328484
#
# Epoch 229
# -------------------------------
# train loss: 0.302897  [    0/ 1201]
#  Avg test loss: 0.322460
#
# Epoch 230
# -------------------------------
# train loss: 0.309070  [    0/ 1201]
#  Avg test loss: 0.334559
#
# Epoch 231
# -------------------------------
# train loss: 0.286738  [    0/ 1201]
#  Avg test loss: 0.313961
#
# Epoch 232
# -------------------------------
# train loss: 0.257084  [    0/ 1201]
#  Avg test loss: 0.312144
#
# Epoch 233
# -------------------------------
# train loss: 0.286750  [    0/ 1201]
#  Avg test loss: 0.302891
#
# Epoch 234
# -------------------------------
# train loss: 0.264748  [    0/ 1201]
#  Avg test loss: 0.319849
#
# Epoch 235
# -------------------------------
# train loss: 0.266079  [    0/ 1201]
#  Avg test loss: 0.350562
#
# Epoch 236
# -------------------------------
# train loss: 0.270463  [    0/ 1201]
#  Avg test loss: 0.318219
#
# Epoch 237
# -------------------------------
# train loss: 0.265374  [    0/ 1201]
#  Avg test loss: 0.333058
#
# Epoch 238
# -------------------------------
# train loss: 0.295936  [    0/ 1201]
#  Avg test loss: 0.333587
#
# Epoch 239
# -------------------------------
# train loss: 0.292468  [    0/ 1201]
#  Avg test loss: 0.309671
#
# Epoch 240
# -------------------------------
# train loss: 0.263930  [    0/ 1201]
#  Avg test loss: 0.346703
#
# Epoch 241
# -------------------------------
# train loss: 0.308598  [    0/ 1201]
#  Avg test loss: 0.305022
#
# Epoch 242
# -------------------------------
# train loss: 0.281063  [    0/ 1201]
#  Avg test loss: 0.321741
#
# Epoch 243
# -------------------------------
# train loss: 0.267616  [    0/ 1201]
#  Avg test loss: 0.315179
#
# Epoch 244
# -------------------------------
# train loss: 0.268383  [    0/ 1201]
#  Avg test loss: 0.324916
#
# Epoch 245
# -------------------------------
# train loss: 0.303668  [    0/ 1201]
#  Avg test loss: 0.308427
#
# Epoch 246
# -------------------------------
# train loss: 0.269213  [    0/ 1201]
#  Avg test loss: 0.335364
#
# Epoch 247
# -------------------------------
# train loss: 0.298391  [    0/ 1201]
#  Avg test loss: 0.339166
#
# Epoch 248
# -------------------------------
# train loss: 0.310678  [    0/ 1201]
#  Avg test loss: 0.312077
#
# Epoch 249
# -------------------------------
# train loss: 0.267618  [    0/ 1201]
#  Avg test loss: 0.332815
#
# Epoch 250
# -------------------------------
# train loss: 0.253822  [    0/ 1201]
#  Avg test loss: 0.336775
#
# Epoch 251
# -------------------------------
# train loss: 0.286578  [    0/ 1201]
#  Avg test loss: 0.330525
#
# Epoch 252
# -------------------------------
# train loss: 0.280817  [    0/ 1201]
#  Avg test loss: 0.303154
#
# Epoch 253
# -------------------------------
# train loss: 0.261879  [    0/ 1201]
#  Avg test loss: 0.338155
#
# Epoch 254
# -------------------------------
# train loss: 0.265863  [    0/ 1201]
#  Avg test loss: 0.335154
#
# Epoch 255
# -------------------------------
# train loss: 0.299860  [    0/ 1201]
#  Avg test loss: 0.334297
#
# Epoch 256
# -------------------------------
# train loss: 0.253300  [    0/ 1201]
#  Avg test loss: 0.300175
#
# Epoch 257
# -------------------------------
# train loss: 0.249900  [    0/ 1201]
#  Avg test loss: 0.327828
#
# Epoch 258
# -------------------------------
# train loss: 0.283070  [    0/ 1201]
#  Avg test loss: 0.323866
#
# Epoch 259
# -------------------------------
# train loss: 0.271163  [    0/ 1201]
#  Avg test loss: 0.339987
#
# Epoch 260
# -------------------------------
# train loss: 0.279230  [    0/ 1201]
#  Avg test loss: 0.322042
#
# Epoch 261
# -------------------------------
# train loss: 0.299586  [    0/ 1201]
#  Avg test loss: 0.297438
#
# Epoch 262
# -------------------------------
# train loss: 0.288247  [    0/ 1201]
#  Avg test loss: 0.317150
#
# Epoch 263
# -------------------------------
# train loss: 0.272256  [    0/ 1201]
#  Avg test loss: 0.337836
#
# Epoch 264
# -------------------------------
# train loss: 0.274839  [    0/ 1201]
#  Avg test loss: 0.315047
#
# Epoch 265
# -------------------------------
# train loss: 0.292442  [    0/ 1201]
#  Avg test loss: 0.343771
#
# Epoch 266
# -------------------------------
# train loss: 0.274789  [    0/ 1201]
#  Avg test loss: 0.361831
#
# Epoch 267
# -------------------------------
# train loss: 0.304143  [    0/ 1201]
#  Avg test loss: 0.327427
#
# Epoch 268
# -------------------------------
# train loss: 0.299447  [    0/ 1201]
#  Avg test loss: 0.345898
#
# Epoch 269
# -------------------------------
# train loss: 0.294043  [    0/ 1201]
#  Avg test loss: 0.320658
#
# Epoch 270
# -------------------------------
# train loss: 0.301295  [    0/ 1201]
#  Avg test loss: 0.299484
#
# Epoch 271
# -------------------------------
# train loss: 0.286144  [    0/ 1201]
#  Avg test loss: 0.312177
#
# Epoch 272
# -------------------------------
# train loss: 0.281316  [    0/ 1201]
#  Avg test loss: 0.339278
#
# Epoch 273
# -------------------------------
# train loss: 0.319650  [    0/ 1201]
#  Avg test loss: 0.344936
#
# Epoch 274
# -------------------------------
# train loss: 0.249776  [    0/ 1201]
#  Avg test loss: 0.339203
#
# Epoch 275
# -------------------------------
# train loss: 0.289870  [    0/ 1201]
#  Avg test loss: 0.309894
#
# Epoch 276
# -------------------------------
# train loss: 0.315673  [    0/ 1201]
#  Avg test loss: 0.336800
#
# Epoch 277
# -------------------------------
# train loss: 0.283846  [    0/ 1201]
#  Avg test loss: 0.348036
#
# Epoch 278
# -------------------------------
# train loss: 0.270724  [    0/ 1201]
#  Avg test loss: 0.321264
#
# Epoch 279
# -------------------------------
# train loss: 0.295899  [    0/ 1201]
#  Avg test loss: 0.317810
#
# Epoch 280
# -------------------------------
# train loss: 0.286748  [    0/ 1201]
#  Avg test loss: 0.323287
#
# Epoch 281
# -------------------------------
# train loss: 0.297134  [    0/ 1201]
#  Avg test loss: 0.342560
#
# Epoch 282
# -------------------------------
# train loss: 0.273928  [    0/ 1201]
#  Avg test loss: 0.309198
#
# Epoch 283
# -------------------------------
# train loss: 0.305387  [    0/ 1201]
#  Avg test loss: 0.307252
#
# Epoch 284
# -------------------------------
# train loss: 0.288346  [    0/ 1201]
#  Avg test loss: 0.343942
#
# Epoch 285
# -------------------------------
# train loss: 0.273331  [    0/ 1201]
#  Avg test loss: 0.324810
#
# Epoch 286
# -------------------------------
# train loss: 0.290464  [    0/ 1201]
#  Avg test loss: 0.309620
#
# Epoch 287
# -------------------------------
# train loss: 0.291377  [    0/ 1201]
#  Avg test loss: 0.338716
#
# Epoch 288
# -------------------------------
# train loss: 0.240436  [    0/ 1201]
#  Avg test loss: 0.322477
#
# Epoch 289
# -------------------------------
# train loss: 0.292024  [    0/ 1201]
#  Avg test loss: 0.334977
#
# Epoch 290
# -------------------------------
# train loss: 0.273288  [    0/ 1201]
#  Avg test loss: 0.330766
#
# Epoch 291
# -------------------------------
# train loss: 0.282860  [    0/ 1201]
#  Avg test loss: 0.322591
#
# Epoch 292
# -------------------------------
# train loss: 0.276320  [    0/ 1201]
#  Avg test loss: 0.323010
#
# Epoch 293
# -------------------------------
# train loss: 0.263430  [    0/ 1201]
#  Avg test loss: 0.342966
#
# Epoch 294
# -------------------------------
# train loss: 0.281815  [    0/ 1201]
#  Avg test loss: 0.346384
#
# Epoch 295
# -------------------------------
# train loss: 0.264691  [    0/ 1201]
#  Avg test loss: 0.315210
#
# Epoch 296
# -------------------------------
# train loss: 0.298149  [    0/ 1201]
#  Avg test loss: 0.333100
#
# Epoch 297
# -------------------------------
# train loss: 0.278991  [    0/ 1201]
#  Avg test loss: 0.355892
#
# Epoch 298
# -------------------------------
# train loss: 0.272261  [    0/ 1201]
#  Avg test loss: 0.319175
#
# Epoch 299
# -------------------------------
# train loss: 0.281496  [    0/ 1201]
#  Avg test loss: 0.328723
#
# Epoch 300
# -------------------------------
# train loss: 0.286831  [    0/ 1201]
#  Avg test loss: 0.316627
#
# Epoch 301
# -------------------------------
# train loss: 0.281544  [    0/ 1201]
#  Avg test loss: 0.329705
#
# Epoch 302
# -------------------------------
# train loss: 0.296064  [    0/ 1201]
#  Avg test loss: 0.344017
#
# Epoch 303
# -------------------------------
# train loss: 0.251639  [    0/ 1201]
#  Avg test loss: 0.361176
#
# Epoch 304
# -------------------------------
# train loss: 0.312284  [    0/ 1201]
#  Avg test loss: 0.326092
#
# Epoch 305
# -------------------------------
# train loss: 0.280313  [    0/ 1201]
#  Avg test loss: 0.314200
#
# Epoch 306
# -------------------------------
# train loss: 0.318237  [    0/ 1201]
#  Avg test loss: 0.333533
#
# Epoch 307
# -------------------------------
# train loss: 0.303784  [    0/ 1201]
#  Avg test loss: 0.324132
#
# Epoch 308
# -------------------------------
# train loss: 0.303334  [    0/ 1201]
#  Avg test loss: 0.351792
#
# Epoch 309
# -------------------------------
# train loss: 0.283464  [    0/ 1201]
#  Avg test loss: 0.334893
#
# Epoch 310
# -------------------------------
# train loss: 0.283997  [    0/ 1201]
#  Avg test loss: 0.305941
#
# Epoch 311
# -------------------------------
# train loss: 0.261753  [    0/ 1201]
#  Avg test loss: 0.353450
#
# Epoch 312
# -------------------------------
# train loss: 0.290510  [    0/ 1201]
#  Avg test loss: 0.333555
#
# Epoch 313
# -------------------------------
# train loss: 0.265297  [    0/ 1201]
#  Avg test loss: 0.331455
#
# Epoch 314
# -------------------------------
# train loss: 0.262953  [    0/ 1201]
#  Avg test loss: 0.349546
#
# Epoch 315
# -------------------------------
# train loss: 0.272507  [    0/ 1201]
#  Avg test loss: 0.329610
#
# Epoch 316
# -------------------------------
# train loss: 0.274366  [    0/ 1201]
#  Avg test loss: 0.306147
#
# Epoch 317
# -------------------------------
# train loss: 0.281197  [    0/ 1201]
#  Avg test loss: 0.320977
#
# Epoch 318
# -------------------------------
# train loss: 0.288480  [    0/ 1201]
#  Avg test loss: 0.355311
#
# Epoch 319
# -------------------------------
# train loss: 0.271589  [    0/ 1201]
#  Avg test loss: 0.333984
#
# Epoch 320
# -------------------------------
# train loss: 0.314008  [    0/ 1201]
#  Avg test loss: 0.330666
#
# Epoch 321
# -------------------------------
# train loss: 0.304832  [    0/ 1201]
#  Avg test loss: 0.323363
#
# Epoch 322
# -------------------------------
# train loss: 0.272539  [    0/ 1201]
#  Avg test loss: 0.317711
#
# Epoch 323
# -------------------------------
# train loss: 0.286777  [    0/ 1201]
#  Avg test loss: 0.350744
#
# Epoch 324
# -------------------------------
# train loss: 0.298936  [    0/ 1201]
#  Avg test loss: 0.329090
#
# Epoch 325
# -------------------------------
# train loss: 0.251528  [    0/ 1201]
#  Avg test loss: 0.320134
#
# Epoch 326
# -------------------------------
# train loss: 0.303036  [    0/ 1201]
#  Avg test loss: 0.349176
#
# Epoch 327
# -------------------------------
# train loss: 0.274304  [    0/ 1201]
#  Avg test loss: 0.312834
#
# Epoch 328
# -------------------------------
# train loss: 0.265847  [    0/ 1201]
#  Avg test loss: 0.329354
#
# Epoch 329
# -------------------------------
# train loss: 0.293244  [    0/ 1201]
#  Avg test loss: 0.329137
#
# Epoch 330
# -------------------------------
# train loss: 0.245108  [    0/ 1201]
#  Avg test loss: 0.337125
#
# Epoch 331
# -------------------------------
# train loss: 0.279333  [    0/ 1201]
#  Avg test loss: 0.333512
#
# Epoch 332
# -------------------------------
# train loss: 0.305602  [    0/ 1201]
#  Avg test loss: 0.331584
#
# Epoch 333
# -------------------------------
# train loss: 0.270972  [    0/ 1201]
#  Avg test loss: 0.322297
#
# Epoch 334
# -------------------------------
# train loss: 0.302394  [    0/ 1201]
#  Avg test loss: 0.347069
#
# Epoch 335
# -------------------------------
# train loss: 0.257731  [    0/ 1201]
#  Avg test loss: 0.346593
#
# Epoch 336
# -------------------------------
# train loss: 0.275338  [    0/ 1201]
#  Avg test loss: 0.314676
#
# Epoch 337
# -------------------------------
# train loss: 0.292524  [    0/ 1201]
#  Avg test loss: 0.310599
#
# Epoch 338
# -------------------------------
# train loss: 0.271321  [    0/ 1201]
#  Avg test loss: 0.343381
#
# Epoch 339
# -------------------------------
# train loss: 0.275856  [    0/ 1201]
#  Avg test loss: 0.333035
#
# Epoch 340
# -------------------------------
# train loss: 0.274747  [    0/ 1201]
#  Avg test loss: 0.328850
#
# Epoch 341
# -------------------------------
# train loss: 0.286597  [    0/ 1201]
#  Avg test loss: 0.304001
#
# Epoch 342
# -------------------------------
# train loss: 0.288227  [    0/ 1201]
#  Avg test loss: 0.324387
#
# Epoch 343
# -------------------------------
# train loss: 0.243036  [    0/ 1201]
#  Avg test loss: 0.328923
#
# Epoch 344
# -------------------------------
# train loss: 0.272382  [    0/ 1201]
#  Avg test loss: 0.320553
#
# Epoch 345
# -------------------------------
# train loss: 0.284241  [    0/ 1201]
#  Avg test loss: 0.317746
#
# Epoch 346
# -------------------------------
# train loss: 0.301450  [    0/ 1201]
#  Avg test loss: 0.310769
#
# Epoch 347
# -------------------------------
# train loss: 0.299090  [    0/ 1201]
#  Avg test loss: 0.310286
#
# Epoch 348
# -------------------------------
# train loss: 0.270906  [    0/ 1201]
#  Avg test loss: 0.348621
#
# Epoch 349
# -------------------------------
# train loss: 0.272556  [    0/ 1201]
#  Avg test loss: 0.319896
#
# Epoch 350
# -------------------------------
# train loss: 0.274367  [    0/ 1201]
#  Avg test loss: 0.321093
#
# Epoch 351
# -------------------------------
# train loss: 0.288549  [    0/ 1201]
#  Avg test loss: 0.318253
#
# Epoch 352
# -------------------------------
# train loss: 0.293213  [    0/ 1201]
#  Avg test loss: 0.336685
#
# Epoch 353
# -------------------------------
# train loss: 0.286169  [    0/ 1201]
#  Avg test loss: 0.322953
#
# Epoch 354
# -------------------------------
# train loss: 0.274625  [    0/ 1201]
#  Avg test loss: 0.329111
#
# Epoch 355
# -------------------------------
# train loss: 0.273487  [    0/ 1201]
#  Avg test loss: 0.312743
#
# Epoch 356
# -------------------------------
# train loss: 0.301248  [    0/ 1201]
#  Avg test loss: 0.326137
#
# Epoch 357
# -------------------------------
# train loss: 0.259797  [    0/ 1201]
#  Avg test loss: 0.338904
#
# Epoch 358
# -------------------------------
# train loss: 0.293376  [    0/ 1201]
#  Avg test loss: 0.349029
#
# Epoch 359
# -------------------------------
# train loss: 0.305186  [    0/ 1201]
#  Avg test loss: 0.331137
#
# Epoch 360
# -------------------------------
# train loss: 0.298549  [    0/ 1201]
#  Avg test loss: 0.352930
#
# Epoch 361
# -------------------------------
# train loss: 0.302166  [    0/ 1201]
#  Avg test loss: 0.296671
#
# Epoch 362
# -------------------------------
# train loss: 0.289334  [    0/ 1201]
#  Avg test loss: 0.332396
#
# Epoch 363
# -------------------------------
# train loss: 0.290812  [    0/ 1201]
#  Avg test loss: 0.339944
#
# Epoch 364
# -------------------------------
# train loss: 0.319252  [    0/ 1201]
#  Avg test loss: 0.335570
#
# Epoch 365
# -------------------------------
# train loss: 0.293450  [    0/ 1201]
#  Avg test loss: 0.326786
#
# Epoch 366
# -------------------------------
# train loss: 0.277380  [    0/ 1201]
#  Avg test loss: 0.333031
#
# Epoch 367
# -------------------------------
# train loss: 0.280560  [    0/ 1201]
#  Avg test loss: 0.319733
#
# Epoch 368
# -------------------------------
# train loss: 0.333926  [    0/ 1201]
#  Avg test loss: 0.324684
#
# Epoch 369
# -------------------------------
# train loss: 0.303382  [    0/ 1201]
#  Avg test loss: 0.346382
#
# Epoch 370
# -------------------------------
# train loss: 0.321847  [    0/ 1201]
#  Avg test loss: 0.323197
#
# Epoch 371
# -------------------------------
# train loss: 0.252470  [    0/ 1201]
#  Avg test loss: 0.345527
#
# Epoch 372
# -------------------------------
# train loss: 0.275691  [    0/ 1201]
#  Avg test loss: 0.324516
#
# Epoch 373
# -------------------------------
# train loss: 0.312473  [    0/ 1201]
#  Avg test loss: 0.319745
#
# Epoch 374
# -------------------------------
# train loss: 0.261295  [    0/ 1201]
#  Avg test loss: 0.327283
#
# Epoch 375
# -------------------------------
# train loss: 0.274265  [    0/ 1201]
#  Avg test loss: 0.319112
#
# Epoch 376
# -------------------------------
# train loss: 0.279999  [    0/ 1201]
#  Avg test loss: 0.350372
#
# Epoch 377
# -------------------------------
# train loss: 0.271052  [    0/ 1201]
#  Avg test loss: 0.351795
#
# Epoch 378
# -------------------------------
# train loss: 0.279663  [    0/ 1201]
#  Avg test loss: 0.318209
#
# Epoch 379
# -------------------------------
# train loss: 0.282838  [    0/ 1201]
#  Avg test loss: 0.330140
#
# Epoch 380
# -------------------------------
# train loss: 0.311711  [    0/ 1201]
#  Avg test loss: 0.324347
#
# Epoch 381
# -------------------------------
# train loss: 0.279826  [    0/ 1201]
#  Avg test loss: 0.318175
#
# Epoch 382
# -------------------------------
# train loss: 0.267088  [    0/ 1201]
#  Avg test loss: 0.333047
#
# Epoch 383
# -------------------------------
# train loss: 0.285229  [    0/ 1201]
#  Avg test loss: 0.334050
#
# Epoch 384
# -------------------------------
# train loss: 0.282611  [    0/ 1201]
#  Avg test loss: 0.336378
#
# Epoch 385
# -------------------------------
# train loss: 0.296427  [    0/ 1201]
#  Avg test loss: 0.342778
#
# Epoch 386
# -------------------------------
# train loss: 0.283269  [    0/ 1201]
#  Avg test loss: 0.336424
#
# Epoch 387
# -------------------------------
# train loss: 0.256748  [    0/ 1201]
#  Avg test loss: 0.338973
#
# Epoch 388
# -------------------------------
# train loss: 0.295997  [    0/ 1201]
#  Avg test loss: 0.365855
#
# Epoch 389
# -------------------------------
# train loss: 0.270882  [    0/ 1201]
#  Avg test loss: 0.346822
#
# Epoch 390
# -------------------------------
# train loss: 0.300392  [    0/ 1201]
#  Avg test loss: 0.342860
#
# Epoch 391
# -------------------------------
# train loss: 0.277303  [    0/ 1201]
#  Avg test loss: 0.332976
#
# Epoch 392
# -------------------------------
# train loss: 0.288635  [    0/ 1201]
#  Avg test loss: 0.335125
#
# Epoch 393
# -------------------------------
# train loss: 0.281749  [    0/ 1201]
#  Avg test loss: 0.342799
#
# Epoch 394
# -------------------------------
# train loss: 0.275333  [    0/ 1201]
#  Avg test loss: 0.323658
#
# Epoch 395
# -------------------------------
# train loss: 0.287153  [    0/ 1201]
#  Avg test loss: 0.341764
#
# Epoch 396
# -------------------------------
# train loss: 0.291571  [    0/ 1201]
#  Avg test loss: 0.344243
#
# Epoch 397
# -------------------------------
# train loss: 0.273227  [    0/ 1201]
#  Avg test loss: 0.319571
#
# Epoch 398
# -------------------------------
# train loss: 0.303589  [    0/ 1201]
#  Avg test loss: 0.331338
#
# Epoch 399
# -------------------------------
# train loss: 0.286920  [    0/ 1201]
#  Avg test loss: 0.326907
#
# Epoch 400
# -------------------------------
# train loss: 0.279267  [    0/ 1201]
#  Avg test loss: 0.330649
#
# Epoch 401
# -------------------------------
# train loss: 0.280136  [    0/ 1201]
#  Avg test loss: 0.331891
#
# Epoch 402
# -------------------------------
# train loss: 0.284541  [    0/ 1201]
#  Avg test loss: 0.338992
#
# Epoch 403
# -------------------------------
# train loss: 0.276245  [    0/ 1201]
#  Avg test loss: 0.333484
#
# Epoch 404
# -------------------------------
# train loss: 0.283168  [    0/ 1201]
#  Avg test loss: 0.354659
#
# Epoch 405
# -------------------------------
# train loss: 0.287762  [    0/ 1201]
#  Avg test loss: 0.331912
#
# Epoch 406
# -------------------------------
# train loss: 0.306295  [    0/ 1201]
#  Avg test loss: 0.332120
#
# Epoch 407
# -------------------------------
# train loss: 0.272437  [    0/ 1201]
#  Avg test loss: 0.349270
#
# Epoch 408
# -------------------------------
# train loss: 0.256866  [    0/ 1201]
#  Avg test loss: 0.316658
#
# Epoch 409
# -------------------------------
# train loss: 0.298976  [    0/ 1201]
#  Avg test loss: 0.322225
#
# Epoch 410
# -------------------------------
# train loss: 0.270201  [    0/ 1201]
#  Avg test loss: 0.315891
#
# Epoch 411
# -------------------------------
# train loss: 0.297419  [    0/ 1201]
#  Avg test loss: 0.312105
#
# Epoch 412
# -------------------------------
# train loss: 0.290878  [    0/ 1201]
#  Avg test loss: 0.339047
#
# Epoch 413
# -------------------------------
# train loss: 0.262922  [    0/ 1201]
#  Avg test loss: 0.331914
#
# Epoch 414
# -------------------------------
# train loss: 0.316099  [    0/ 1201]
#  Avg test loss: 0.320897
#
# Epoch 415
# -------------------------------
# train loss: 0.262612  [    0/ 1201]
#  Avg test loss: 0.344333
#
# Epoch 416
# -------------------------------
# train loss: 0.292289  [    0/ 1201]
#  Avg test loss: 0.317734
#
# Epoch 417
# -------------------------------
# train loss: 0.271971  [    0/ 1201]
#  Avg test loss: 0.332203
#
# Epoch 418
# -------------------------------
# train loss: 0.273578  [    0/ 1201]
#  Avg test loss: 0.344932
#
# Epoch 419
# -------------------------------
# train loss: 0.281920  [    0/ 1201]
#  Avg test loss: 0.332410
#
# Epoch 420
# -------------------------------
# train loss: 0.286143  [    0/ 1201]
#  Avg test loss: 0.313045
#
# Epoch 421
# -------------------------------
# train loss: 0.282079  [    0/ 1201]
#  Avg test loss: 0.321778
#
# Epoch 422
# -------------------------------
# train loss: 0.274444  [    0/ 1201]
#  Avg test loss: 0.346036
#
# Epoch 423
# -------------------------------
# train loss: 0.258666  [    0/ 1201]
#  Avg test loss: 0.327108
#
# Epoch 424
# -------------------------------
# train loss: 0.275692  [    0/ 1201]
#  Avg test loss: 0.350857
#
# Epoch 425
# -------------------------------
# train loss: 0.285560  [    0/ 1201]
#  Avg test loss: 0.332685
#
# Epoch 426
# -------------------------------
# train loss: 0.275126  [    0/ 1201]
#  Avg test loss: 0.346237
#
# Epoch 427
# -------------------------------
# train loss: 0.263144  [    0/ 1201]
#  Avg test loss: 0.332720
#
# Epoch 428
# -------------------------------
# train loss: 0.265496  [    0/ 1201]
#  Avg test loss: 0.321805
#
# Epoch 429
# -------------------------------
# train loss: 0.256768  [    0/ 1201]
#  Avg test loss: 0.328659
#
# Epoch 430
# -------------------------------
# train loss: 0.314817  [    0/ 1201]
#  Avg test loss: 0.341660
#
# Epoch 431
# -------------------------------
# train loss: 0.267732  [    0/ 1201]
#  Avg test loss: 0.364140
#
# Epoch 432
# -------------------------------
# train loss: 0.313080  [    0/ 1201]
#  Avg test loss: 0.361975
#
# Epoch 433
# -------------------------------
# train loss: 0.266709  [    0/ 1201]
#  Avg test loss: 0.347380
#
# Epoch 434
# -------------------------------
# train loss: 0.289220  [    0/ 1201]
#  Avg test loss: 0.332891
#
# Epoch 435
# -------------------------------
# train loss: 0.272593  [    0/ 1201]
#  Avg test loss: 0.332136
#
# Epoch 436
# -------------------------------
# train loss: 0.260866  [    0/ 1201]
#  Avg test loss: 0.351079
#
# Epoch 437
# -------------------------------
# train loss: 0.300858  [    0/ 1201]
#  Avg test loss: 0.333015
#
# Epoch 438
# -------------------------------
# train loss: 0.302786  [    0/ 1201]
#  Avg test loss: 0.324372
#
# Epoch 439
# -------------------------------
# train loss: 0.258979  [    0/ 1201]
#  Avg test loss: 0.313180
#
# Epoch 440
# -------------------------------
# train loss: 0.264407  [    0/ 1201]
#  Avg test loss: 0.344137
#
# Epoch 441
# -------------------------------
# train loss: 0.261999  [    0/ 1201]
#  Avg test loss: 0.319192
#
# Epoch 442
# -------------------------------
# train loss: 0.277191  [    0/ 1201]
#  Avg test loss: 0.328832
#
# Epoch 443
# -------------------------------
# train loss: 0.269468  [    0/ 1201]
#  Avg test loss: 0.336349
#
# Epoch 444
# -------------------------------
# train loss: 0.308953  [    0/ 1201]
#  Avg test loss: 0.353259
#
# Epoch 445
# -------------------------------
# train loss: 0.235774  [    0/ 1201]
#  Avg test loss: 0.347443
#
# Epoch 446
# -------------------------------
# train loss: 0.285517  [    0/ 1201]
#  Avg test loss: 0.335150
#
# Epoch 447
# -------------------------------
# train loss: 0.273682  [    0/ 1201]
#  Avg test loss: 0.332135
#
# Epoch 448
# -------------------------------
# train loss: 0.289977  [    0/ 1201]
#  Avg test loss: 0.340686
#
# Epoch 449
# -------------------------------
# train loss: 0.273207  [    0/ 1201]
#  Avg test loss: 0.339823
#
# Epoch 450
# -------------------------------
# train loss: 0.267149  [    0/ 1201]
#  Avg test loss: 0.333284
#
# Epoch 451
# -------------------------------
# train loss: 0.247582  [    0/ 1201]
#  Avg test loss: 0.332409
#
# Epoch 452
# -------------------------------
# train loss: 0.309812  [    0/ 1201]
#  Avg test loss: 0.346321
#
# Epoch 453
# -------------------------------
# train loss: 0.279745  [    0/ 1201]
#  Avg test loss: 0.358049
#
# Epoch 454
# -------------------------------
# train loss: 0.310940  [    0/ 1201]
#  Avg test loss: 0.328237
#
# Epoch 455
# -------------------------------
# train loss: 0.293849  [    0/ 1201]
#  Avg test loss: 0.333639
#
# Epoch 456
# -------------------------------
# train loss: 0.277188  [    0/ 1201]
#  Avg test loss: 0.344037
#
# Epoch 457
# -------------------------------
# train loss: 0.284578  [    0/ 1201]
#  Avg test loss: 0.345413
#
# Epoch 458
# -------------------------------
# train loss: 0.295296  [    0/ 1201]
#  Avg test loss: 0.342305
#
# Epoch 459
# -------------------------------
# train loss: 0.258479  [    0/ 1201]
#  Avg test loss: 0.320261
#
# Epoch 460
# -------------------------------
# train loss: 0.304386  [    0/ 1201]
#  Avg test loss: 0.357383
#
# Epoch 461
# -------------------------------
# train loss: 0.261306  [    0/ 1201]
#  Avg test loss: 0.339834
#
# Epoch 462
# -------------------------------
# train loss: 0.327918  [    0/ 1201]
#  Avg test loss: 0.340500
#
# Epoch 463
# -------------------------------
# train loss: 0.281466  [    0/ 1201]
#  Avg test loss: 0.318917
#
# Epoch 464
# -------------------------------
# train loss: 0.293195  [    0/ 1201]
#  Avg test loss: 0.336976
#
# Epoch 465
# -------------------------------
# train loss: 0.274384  [    0/ 1201]
#  Avg test loss: 0.355844
#
# Epoch 466
# -------------------------------
# train loss: 0.281995  [    0/ 1201]
#  Avg test loss: 0.355071
#
# Epoch 467
# -------------------------------
# train loss: 0.276493  [    0/ 1201]
#  Avg test loss: 0.354255
#
# Epoch 468
# -------------------------------
# train loss: 0.247649  [    0/ 1201]
#  Avg test loss: 0.335250
#
# Epoch 469
# -------------------------------
# train loss: 0.270015  [    0/ 1201]
#  Avg test loss: 0.315648
#
# Epoch 470
# -------------------------------
# train loss: 0.266866  [    0/ 1201]
#  Avg test loss: 0.335995
#
# Epoch 471
# -------------------------------
# train loss: 0.302932  [    0/ 1201]
#  Avg test loss: 0.334679
#
# Epoch 472
# -------------------------------
# train loss: 0.265678  [    0/ 1201]
#  Avg test loss: 0.332656
#
# Epoch 473
# -------------------------------
# train loss: 0.282024  [    0/ 1201]
#  Avg test loss: 0.339445
#
# Epoch 474
# -------------------------------
# train loss: 0.278949  [    0/ 1201]
#  Avg test loss: 0.320619
#
# Epoch 475
# -------------------------------
# train loss: 0.291822  [    0/ 1201]
#  Avg test loss: 0.333746
#
# Epoch 476
# -------------------------------
# train loss: 0.289984  [    0/ 1201]
#  Avg test loss: 0.346663
#
# Epoch 477
# -------------------------------
# train loss: 0.295014  [    0/ 1201]
#  Avg test loss: 0.343791
#
# Epoch 478
# -------------------------------
# train loss: 0.275209  [    0/ 1201]
#  Avg test loss: 0.351474
#
# Epoch 479
# -------------------------------
# train loss: 0.283858  [    0/ 1201]
#  Avg test loss: 0.343099
#
# Epoch 480
# -------------------------------
# train loss: 0.251799  [    0/ 1201]
#  Avg test loss: 0.334045
#
# Epoch 481
# -------------------------------
# train loss: 0.278258  [    0/ 1201]
#  Avg test loss: 0.300191
#
# Epoch 482
# -------------------------------
# train loss: 0.260684  [    0/ 1201]
#  Avg test loss: 0.354498
#
# Epoch 483
# -------------------------------
# train loss: 0.291619  [    0/ 1201]
#  Avg test loss: 0.332902
#
# Epoch 484
# -------------------------------
# train loss: 0.261158  [    0/ 1201]
#  Avg test loss: 0.331369
#
# Epoch 485
# -------------------------------
# train loss: 0.282830  [    0/ 1201]
#  Avg test loss: 0.340158
#
# Epoch 486
# -------------------------------
# train loss: 0.253881  [    0/ 1201]
#  Avg test loss: 0.333135
#
# Epoch 487
# -------------------------------
# train loss: 0.264579  [    0/ 1201]
#  Avg test loss: 0.340854
#
# Epoch 488
# -------------------------------
# train loss: 0.257470  [    0/ 1201]
#  Avg test loss: 0.351833
#
# Epoch 489
# -------------------------------
# train loss: 0.315645  [    0/ 1201]
#  Avg test loss: 0.324392
#
# Epoch 490
# -------------------------------
# train loss: 0.283274  [    0/ 1201]
#  Avg test loss: 0.318105
#
# Epoch 491
# -------------------------------
# train loss: 0.275465  [    0/ 1201]
#  Avg test loss: 0.330520
#
# Epoch 492
# -------------------------------
# train loss: 0.286696  [    0/ 1201]
#  Avg test loss: 0.343318
#
# Epoch 493
# -------------------------------
# train loss: 0.288660  [    0/ 1201]
#  Avg test loss: 0.309915
#
# Epoch 494
# -------------------------------
# train loss: 0.290437  [    0/ 1201]
#  Avg test loss: 0.343418
#
# Epoch 495
# -------------------------------
# train loss: 0.309371  [    0/ 1201]
#  Avg test loss: 0.328468
#
# Epoch 496
# -------------------------------
# train loss: 0.286804  [    0/ 1201]
#  Avg test loss: 0.313695
#
# Epoch 497
# -------------------------------
# train loss: 0.269733  [    0/ 1201]
#  Avg test loss: 0.344251
#
# Epoch 498
# -------------------------------
# train loss: 0.280545  [    0/ 1201]
#  Avg test loss: 0.344355
#
# Epoch 499
# -------------------------------
# train loss: 0.267627  [    0/ 1201]
#  Avg test loss: 0.336934
#
# Epoch 500
# -------------------------------
# train loss: 0.262836  [    0/ 1201]
#  Avg test loss: 0.339577
#
# Done!

# %%
plot_train_loss = [x[-1] for x in train_loss]

# %%
epochs = range(1, len(train_loss) + 1)  # Epochs are 1-based indexing

plt.figure(figsize=(10, 6))
plt.plot(epochs, plot_train_loss, label='Training Loss', marker='o')
plt.plot(epochs, test_loss, label='Test Loss', marker='x')
plt.title('Objective Function vs. Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
vis_loader = DataLoader(test_dataset, batch_size=16, shuffle=True) # get 16 random spectra

for X_batch, y_batch in vis_loader:
    # Simulated x-axis values for the spectrum
    x = np.linspace(0, features.shape[1], features.shape[1])
    
    with torch.no_grad():
        preds = AE(X_batch).detach()
    
    for i in range(len(X_batch)):
        plt.figure(figsize=(10, 6))
        plt.plot(x, X_batch[i].numpy(), label='Actual Spectrum')  # Converting tensor to numpy array for plotting
        plt.plot(x, preds[i].numpy(), label='Reconstructed Spectrum',linestyle='--')
        plt.title(f'Spectrum {i+1} of type {y_batch[i]}')
        plt.xlabel('Data Point Index')
        plt.ylabel('Intensity')
        plt.legend()
        plt.grid(True)
    break # just need one batch of 16

# %%
preds = []
labls = []
for X_batch, y_batch in test_dataloader:
    with torch.no_grad():
        preds.append(AE.encoder(X_batch).detach())
        labls += y_batch

preds = torch.cat(preds)

import itertools

# Assuming `preds` is your 5-dimensional encoded tensor
# Example: preds = torch.randn(100, 5)  # Random data for illustration

# Generate all combinations of the 5 coordinates taken 2 at a time
combos = list(itertools.combinations(range(5), 2))

# Create plots for all combinations
fig, axs = plt.subplots(5, 2, figsize=(15, 25))  # Adjust subplot grid as needed

for i, (idx1, idx2) in enumerate(combos):
    ax = axs[i//2, i%2]  # Determine the subplot for the current combo
    scatter = ax.scatter(preds[:, idx1].numpy(), preds[:, idx2].numpy())
    ax.set_title(f'Scatter Plot of Coordinates {idx1+1} vs {idx2+1}')
    ax.set_xlabel(f'Coordinate {idx1+1}')
    ax.set_ylabel(f'Coordinate {idx2+1}')
    ax.grid(True)

    cbar = fig.colorbar(scatter, ax=ax)
    cbar.set_label('Label')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create a scatter plot
scatter = ax.scatter(preds[:, 0].numpy(), preds[:, 3].numpy(), preds[:, 4].numpy())

# Add labels and title
ax.set_xlabel('Coordinate 1')
ax.set_ylabel('Coordinate 4')
ax.set_zlabel('Coordinate 5')
ax.set_title('3D Scatter Plot of Coordinates 1, 4, 5')

# Add a color bar
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Label')

plt.show()

# %%
preds_=preds

# %%
from sklearn.cluster import KMeans

encoded = preds_
kmeans = KMeans(n_clusters=2, random_state=205).fit(encoded)
kmeans
# Out:
# KMeans(n_clusters=2, random_state=205)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[-95.53110957  12.82249636  39.88490247 -49.91267296 -44.8997144 ]
#  [-19.37895666 -15.37052645  27.71516267 -16.96209835 -85.83771495]]

# %%
from matplotlib.lines import Line2D      

ax = plt.subplot(1,1,1)
labls_array = np.array([label.item() for label in labls])
description = ['short','long']

# Use the viridis colormap
colormap = plt.cm.viridis

num_classes = len(description)

# Normalize label values to match the colormap range
normalize = plt.Normalize(vmin=0, vmax=num_classes)

markers = ['*', '.']


for pred_class in range(num_classes):
    total_mask = kmeans.labels_ == pred_class
    ax.scatter(encoded[total_mask,0], encoded[total_mask,4], 
               color=colormap(normalize(pred_class)))

# cluster center
for idx, center in enumerate(kmeans.cluster_centers_):
    ax.scatter(center[0],center[4], color=colormap(normalize(idx)), marker='X', s=100, edgecolors='red')
    
ax.set_xlabel('Coordinate 1')
ax.set_ylabel('Coordinate 5')
ax.set_title("K-means clustering with k=2")
legend_elements = [Line2D([0], [0], marker=markers[i-1], linewidth=0, label=f'Actual cluster {i}, {description[i-1]}',
                           markersize=10) for i in range(1, num_classes+1)]
legend_elements.append(Line2D([0], [0], marker='X', linewidth=0, label=f'Cluster mean',
                           markersize=10,markeredgecolor='red'))
ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
preds = []
labls = []
for X_batch, y_batch in test_dataloader:
    with torch.no_grad():
        preds.append(AE.encoder(X_batch).detach())
        labls += y_batch

preds = torch.cat(preds)

import itertools

# Assuming `preds` is your 5-dimensional encoded tensor
# Example: preds = torch.randn(100, 5)  # Random data for illustration

# Generate all combinations of the 5 coordinates taken 2 at a time
combos = list(itertools.combinations(range(5), 2))

# Create plots for all combinations
fig, axs = plt.subplots(5, 2, figsize=(15, 25))  # Adjust subplot grid as needed

for i, (idx1, idx2) in enumerate(combos):
    ax = axs[i//2, i%2]  # Determine the subplot for the current combo
    scatter = ax.scatter(preds[:, idx1].numpy(), preds[:, idx2].numpy(), c=kmeans.labels_, cmap='viridis')
    ax.set_title(f'Scatter Plot of Coordinates {idx1+1} vs {idx2+1}')
    ax.set_xlabel(f'Coordinate {idx1+1}')
    ax.set_ylabel(f'Coordinate {idx2+1}')
    ax.grid(True)

    cbar = fig.colorbar(scatter, ax=ax)
    cbar.set_label('Label')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create a scatter plot
scatter = ax.scatter(preds[:, 0].numpy(), preds[:, 3].numpy(), preds[:, 4].numpy(), c=kmeans.labels_, cmap='viridis')

# Add labels and title
ax.set_xlabel('Coordinate 1')
ax.set_ylabel('Coordinate 4')
ax.set_zlabel('Coordinate 5')
ax.set_title('3D Scatter Plot of Coordinates 1, 4, 5')

# Add a color bar
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Label')

plt.show()

# %%
features
# Out:
# array([[3.27826857e-04, 8.94158557e-05, 1.61230386e-04, ...,
#         5.67102445e-06, 5.72234663e-06, 2.96175636e-06],
#        [3.26247437e-04, 1.19335501e-04, 1.47172658e-04, ...,
#         5.26937846e-06, 5.17231811e-06, 3.17371014e-06],
#        [3.28534117e-04, 1.15034800e-04, 1.46069436e-04, ...,
#         1.97931459e-05, 1.97771267e-05, 4.15632409e-06],
#        ...,
#        [3.25735628e-04, 1.01520402e-04, 1.52057928e-04, ...,
#         3.70694367e-06, 3.73887097e-06, 1.12846915e-06],
#        [3.36175307e-04, 9.23237967e-05, 1.66581350e-04, ...,
#         1.14179722e-05, 1.13581309e-05, 3.91197238e-05],
#        [3.27824086e-04, 1.04686531e-04, 1.46561857e-04, ...,
#         3.28094678e-05, 3.27161272e-05, 1.60410588e-05]])

# %%
preds2 = []
for x in features:
    with torch.no_grad():
        # Convert x from a NumPy array to a PyTorch tensor
        x_tensor = torch.tensor(x, dtype=torch.float32)
        
        # Add a batch dimension to x
        x_tensor = x_tensor.unsqueeze(0)
        preds2.append(AE.encoder(x_tensor).detach())

preds2 = torch.cat(preds2)
preds2
# Out:
# tensor([[-0.1038,  0.0348,  0.0521, -0.0586, -0.0196],
#         [-0.1058,  0.0344,  0.0516, -0.0580, -0.0190],
#         [-0.1011,  0.0350,  0.0511, -0.0591, -0.0199],
#         ...,
#         [-0.1083,  0.0339,  0.0510, -0.0577, -0.0185],
#         [-0.0984,  0.0339,  0.0504, -0.0583, -0.0193],
#         [-0.1070,  0.0326,  0.0500, -0.0563, -0.0173]])

# %%
encoded2 = preds2
kmeans2 = KMeans(n_clusters=2, random_state=205).fit(encoded2)
kmeans2
# Out:
# KMeans(n_clusters=2, random_state=205)

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create a scatter plot
scatter = ax.scatter(preds2[:, 0].numpy(), preds2[:, 3].numpy(), preds2[:, 4].numpy(), c=kmeans2.labels_, cmap='viridis')

# Add labels and title
ax.set_xlabel('Coordinate 1')
ax.set_ylabel('Coordinate 4')
ax.set_zlabel('Coordinate 5')
ax.set_title('3D Scatter Plot of Coordinates 1, 4, 5')

# Add a color bar
cbar = fig.colorbar(scatter, ax=ax)
cbar.set_label('Label')

plt.show()

# %%
data_loaded = np.load(os.path.join(swift.results_path, f'SWIFT_data_{swift.res}res_{"".join(str(b) for b in swift.n_bands)}bands_DFT_True.npz'))
names_64ms, features_64ms = data_loaded['names'], data_loaded['data']
# Out:
# Finding Durations: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 131/131 [00:06<00:00, 19.88GRB/s]
# Finding Durations: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1371/1371 [00:05<00:00, 229.69GRB/s]
# Text(0, 0.5, 'Number of GRBs')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
match = kmeans2.labels_==1
match2 = kmeans2.labels_==0
names1 = names_64ms[match]
names2 = names_64ms[match2]
swift.duration_histogram(names=[names1, names2], alpha=0.3, color_groups=['r', 'gray'], ax=ax)
ax.axvline(x=np.log10(2), c='k', ls='--', linewidth=1)
ax.set_xlabel(r'log$_{10}(T_{90})$ (s)')
ax.set_ylabel('Number of GRBs')
# Out:
# Finding Durations: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 131/131 [00:05<00:00, 24.11GRB/s]
# Finding Durations: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1371/1371 [00:06<00:00, 211.15GRB/s]
# Text(0, 0.5, 'Number of GRBs')
